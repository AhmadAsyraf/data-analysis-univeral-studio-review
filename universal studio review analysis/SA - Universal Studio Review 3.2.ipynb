# %%
## Sentiment Analysis (https://monkeylearn.com/sentiment-analysis/)

Sentiment analysis (or opinion mining) is a natural language processing (NLP) technique used to determine whether data is positive, negative or neutral. Sentiment analysis is often performed on textual data to help businesses monitor brand and product sentiment in customer feedback, and understand customer needs.

Sentiment analysis is the process of detecting positive or negative sentiment in text. It’s often used by businesses to detect sentiment in social data, gauge brand reputation, and understand customers.

### Types of Sentiment Analysis

Sentiment analysis focuses on the polarity of a text (positive, negative, neutral) but it also goes beyond polarity to detect specific feelings and emotions (angry, happy, sad, etc), urgency (urgent, not urgent) and even intentions (interested vs not interested). Depending on how you want to interpret customer feedback and queries, you can define and tailor your categories to meet your sentiment analysis needs. In the meantime, here are some of the most popular types of sentiment analysis:

<ol>
    <li>Graded Sentiment Analysis - polarity categories ranges from positive-negative</li>
    <li>Emotion Detection - polarity to detect emotion: happiness/frustration/anger/sadness</li>
    <li>Aspect-based Sentiment Analysis - analyse features/aspect determining positive/neutral/negative</li>
    <li>Multilingual Sentiment Analysis - custom sentiment analysis</li>
</ol>


Since humans express their thoughts and feelings more openly than ever before, sentiment analysis is fast becoming an essential tool to monitor and understand sentiment in all types of data. The sentiment analysis result may help in tailoring a products and services to meet their customer needs. Tracking your progress periodically also possible with sentiment analysis - whether changes are made or not.

### Dataset Description

Dataset used: Universal Studio Branches Reviews
Data Analysis for Kaggle Universal Studio Branches Reviews is available in:
https://www.kaggle.com/datasets/dwiknrd/reviewuniversalstudio

Below are the description of the columns/features in the data:

<ul>
    <li>reviewer: name of the reviewer</li>
    <li>rating: 1-5</li>
    <li>written_date: date of the review</li>
    <li>title: title of the review</li>
    <li>review_text: description of the review</li>
    <li>branch: Universal Studios Florida, Universal Studios Japan, Universal Studios Singapore</li>
</ul>

# %% [markdown]
# ##  1. Import all required packages/libraries.

# %%
# import required packages for EDA
import pandas as pd
import numpy as np
import seaborn as sns
import re
import missingno
from collections import Counter
import string
from string import punctuation
import nltk
from nltk.corpus import stopwords

# Install wordcloud in anaconda command prompt
from wordcloud import WordCloud, STOPWORDS

# %%
nltk.download("stopwords")
import matplotlib.pyplot as plt

# Lexicon-based sentiment analysis - install using pip install afinn in anaconda command prompt
from afinn import Afinn

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\srhhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 2. Load the data into the dataframe.

# %%
# Read the .csv file using Pandas into data frame
usb_df = pd.read_csv("universal_studio_branches.csv")

# You may remove or set the index for this data. In this case since there is reviewer, we can set it to our index.
usb_df = usb_df.set_index('reviewer')

# %%
# Display the data - first five & last five. Has 50904 rows & 5 columns.
usb_df
# Out:
#                       rating       written_date  \
# reviewer
# Kelly B                  2.0       May 30, 2021
# Jon                      1.0       May 30, 2021
# Nerdy P                  2.0       May 30, 2021
# ran101278                4.0       May 29, 2021
# tammies20132015          5.0       May 28, 2021
# ...                      ...                ...
# vinz20                   4.0     March 29, 2010
# betty l                  4.0     March 29, 2010
# spoonos65                4.0     March 28, 2010
# HeatSeekerWrexham_UK     4.0     March 22, 2010
# sc_myinitial             5.0  February 24, 2010
#
#                                                                   title  \
# reviewer
# Kelly B               Universal is a complete Disaster - stick with ...
# Jon                                                Food is hard to get.
# Nerdy P                                                    Disappointed
# ran101278                                                    My opinion
# tammies20132015                       The Bourne Stuntacular...MUST SEE
# ...                                                                 ...
# vinz20                                         I'll Be Back Only If ...
# betty l                          Universal Studios Singapore Experience
# spoonos65                            Impressive but not quite finished!
# HeatSeekerWrexham_UK                       Small but beautifully marked
# sc_myinitial                                    Excellent Sneak Preview
#
#                                                             review_text  \
# reviewer
# Kelly B               We went to Universal over Memorial Day weekend...
# Jon                   The food service is horrible. I’m not reviewin...
# Nerdy P               I booked this vacation mainly to ride Hagrid m...
# ran101278             When a person tries the test seat for the ride...
# tammies20132015       Ok, I can't stress enough to anyone and everyo...
# ...                                                                 ...
# vinz20                This is my first visit to a Universal Studio t...
# betty l               We finally visited Singapore's very first them...
# spoonos65             We visited during the first week of its 'soft ...
# HeatSeekerWrexham_UK  We visited on the 3rd day of the 'soft' openin...
# sc_myinitial          My group managed to get the tickets for the 16...
#
#                                            branch
# reviewer
# Kelly B                 Universal Studios Florida
# Jon                     Universal Studios Florida
# Nerdy P                 Universal Studios Florida
# ran101278               Universal Studios Florida
# tammies20132015         Universal Studios Florida
# ...                                           ...
# vinz20                Universal Studios Singapore
# betty l               Universal Studios Singapore
# spoonos65             Universal Studios Singapore
# HeatSeekerWrexham_UK  Universal Studios Singapore
# sc_myinitial          Universal Studios Singapore
#
# [50904 rows x 5 columns]

# %%
# Calling the shape attribute of the universal studio review dataset we can observe that there are 
# 50904 observations/rows and 5 features/columns in the data set
print ("usb_df shape: ", usb_df.shape)
# Out:
# usb_df shape:  (50904, 5)

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
# Exploratory data analysis is the process of visualising and analysing data to extract insights. In other words, we want to summarise important characteristics and trends in our data in order to gain a better understanding of our dataset.

# %% [markdown]
# ### 3.1 Data types, missing data, data cleaning and summary statistics

# %%
print ("Overall data frame shape: ", usb_df.shape)
print("-" * 40)

# Non-null count and data types of the dataset. - all rows is fill with data
usb_df.info()
# Out:
# Overall data frame shape:  (50904, 5)
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 50904 entries, Kelly B to sc_myinitial
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rating        50904 non-null  float64
#  1   written_date  50904 non-null  object
#  2   title         50904 non-null  object
#  3   review_text   50904 non-null  object
#  4   branch        50904 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.3+ MB

# %%
# Missing data in universal studio review data frame by columns
usb_df.isnull().sum().sort_values(ascending = False)
# Out:
# rating          0
# written_date    0
# title           0
# review_text     0
# branch          0
# dtype: int64

# %%
# Missing data in universal studio review set - all rows was fill with data
missingno.matrix(usb_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3.1 Display the column/feature names available in usb_df.

# %%
# Print the column/feature names
print(usb_df.columns.values)
# Out:
# ['rating' 'written_date' 'title' 'review_text' 'branch']

# %% [markdown]
# ### 3.2 Displaying first five and last five records in usb_df.

# %%
# Display the first five rows
usb_df.head()
# Out:
#                  rating  written_date  \
# reviewer
# Kelly B             2.0  May 30, 2021
# Jon                 1.0  May 30, 2021
# Nerdy P             2.0  May 30, 2021
# ran101278           4.0  May 29, 2021
# tammies20132015     5.0  May 28, 2021
#
#                                                              title  \
# reviewer
# Kelly B          Universal is a complete Disaster - stick with ...
# Jon                                           Food is hard to get.
# Nerdy P                                               Disappointed
# ran101278                                               My opinion
# tammies20132015                  The Bourne Stuntacular...MUST SEE
#
#                                                        review_text  \
# reviewer
# Kelly B          We went to Universal over Memorial Day weekend...
# Jon              The food service is horrible. I’m not reviewin...
# Nerdy P          I booked this vacation mainly to ride Hagrid m...
# ran101278        When a person tries the test seat for the ride...
# tammies20132015  Ok, I can't stress enough to anyone and everyo...
#
#                                     branch
# reviewer
# Kelly B          Universal Studios Florida
# Jon              Universal Studios Florida
# Nerdy P          Universal Studios Florida
# ran101278        Universal Studios Florida
# tammies20132015  Universal Studios Florida

# %%
# Display the last five rows
usb_df.tail()
# Out:
#                       rating       written_date  \
# reviewer
# vinz20                   4.0     March 29, 2010
# betty l                  4.0     March 29, 2010
# spoonos65                4.0     March 28, 2010
# HeatSeekerWrexham_UK     4.0     March 22, 2010
# sc_myinitial             5.0  February 24, 2010
#
#                                                        title  \
# reviewer
# vinz20                              I'll Be Back Only If ...
# betty l               Universal Studios Singapore Experience
# spoonos65                 Impressive but not quite finished!
# HeatSeekerWrexham_UK            Small but beautifully marked
# sc_myinitial                         Excellent Sneak Preview
#
#                                                             review_text  \
# reviewer
# vinz20                This is my first visit to a Universal Studio t...
# betty l               We finally visited Singapore's very first them...
# spoonos65             We visited during the first week of its 'soft ...
# HeatSeekerWrexham_UK  We visited on the 3rd day of the 'soft' openin...
# sc_myinitial          My group managed to get the tickets for the 16...
#
#                                            branch
# reviewer
# vinz20                Universal Studios Singapore
# betty l               Universal Studios Singapore
# spoonos65             Universal Studios Singapore
# HeatSeekerWrexham_UK  Universal Studios Singapore
# sc_myinitial          Universal Studios Singapore

# %% [markdown]
# ### 3.3 Displaying & remove duplicate data

# %%
usb_df.value_counts()
# Out:
# rating  written_date        title                                                                    review_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              branch
# 5.0     May 11, 2018        Simply awesome                                                           Simply awesome is the word. Everything is great here, but first you need to have an express pass. Also, as you can use express pass once in each ride, hence if you are here at 10 AM you can do some rides using the normal ticket, and repeat them with express.  By afternoon 3-4 pm,even express pass would have 30 min waiting at all good rides. Do watch the waterworld show that happens at 2PM and then at 5:30 PM. Other recommendations: - Transformers ride - Revenge of the mummy - Battlestar galactica roller coasters - Jurassic park rapids ride (opens at 11 AM)  You may not be able to cover everything in a day even with express, but give your best shot.  Food can be a bit costly, try the Malaysian food court just outside the gate. Do get the stamp while going out.  You can reach here by Sentosa express monorail or even from Sentosa boardwalk (10 min walk from Vivocity)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Universal Studios Singapore    2
# 2.0     November 4, 2007    HHN & Studios wasn't worth it                                            We visit Universal Studios and Halloween Horror Nights last week and the money we spent was not worth what we paid.  Universal Studios - not many rides and it is very different to the backlot tour and feel of Hollywood. There are a lot of 'watching' type rides which wasn't what I had imagined and some were frankly a waste - Naria and ET! Also, the Jaws ride was short but had great themes. The best ride was the Mummy and Twister! We made sure to do these rides/walkthrough a few times. MIB was good too! Shrek 4D and Sponge Bob was good as well. The park is small and can be done in half a day so you can pop across to Islands of Adventure. We bought express passes (online before we left Australia) but they were a total waste of money because the park was not crowded enough and most times Universal wasn't using them.  HHN was not worth the $65USD. We lined up outside the park at 5pm which was a benefit because we got in at the beginning of the night and beat the crowds. We got through 4 of the 7 houses with our longest line being 45 minutes before they blew out to 90+ minutes and we decided to leave the park because it was becoming overcrowded and it felt a bit unsafe to me because of a 'gang' feeling as it got later and people became drunk. The houses we did get through were OK, and, not as scary as the website made them appear, so the fright factor was minor and disappointing. Standing in a long line for a 2 minute walkthrough of the houses did not add up.  Now that we have gone this year, we don't need to ever go again to experience Universal Orlando or HHN. It just wasn't that much fun.                                                                                                                                                                                                                                                                                             Universal Studios Florida      2
# 1.0     February 17, 2011   Do not buy package deals from Universal                                  They do not care about you. I bought a package to stay on the 17th of February when I thought I had bought one from the 10th. I realized when I was printing out the forms on the 10th that my reservation was from the 17th. I called customer service at about 6:45 pm(they close at 7:00 pm) and explained my situation. The customer rep goes of the pohone for a few minutes and comes back and tells me there are no vacancies in any of their 52 hotels. The explanation she gives me is because it;s a friday night. It was not a friday night. It was a thursday. She did not try to find me a night on adjacent days or try to do anything. She didn't even ask me if I wanted to cancel my stay. All she said was, "we have no vacancies in all 52 hotels." Then for cancelation they charge me a $100 fee. She says to me, "It's a good thing you canceled today. It would have been $200 tomorrow." I beleive that she was trying to escape working so close to closing.  Next, after buying my vacation out of pocket, I complained to the appropriate department. They called me and explained to me that because it was a "president's day weekend there were no vacancies". Big mistake. The weekend of the 17th, which I had originally booked was president's day weekend, not the weekend II had booked. Then they offer me a few peanuts by asking me if I want a discount next time I went back to universal studios. I had already told them in the email I would never go back to universal studios again and they offer me a small ticket discount?? After I refused the said discount, they were unwilling to do anything else for me. I see that this is how Universal feels about it's customers and why shouldn't they? No matter how poor their customer service is, they will still get droves of people coming. This is my warning to you. Do not buy their hotel package deals. Go to their park if you must, but it was not that fun.  Universal Studios Florida      2
# 4.0     April 23, 2019      Fun vacation                                                             We had a great time, make sure to book tickets early to do the fast passes. Wait time is extremely long for rides if you dont ( we learned this lesson).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Universal Studios Florida      2
# 5.0     September 14, 2004  Fantastic day of fantasy                                                 Visited Universal Studios thrid week of August '04 with a 5 park flexticket as a single mother with two teenagers. We loved every second of every ride. The Mummy, an indoor rollercoaster, is a must tho I confess I closed my eyes many times - which has been immortalised on a key ring! Terminator 2 was absolutely fantastic - special effects from the screen and your chairs! Superman was a favourite simulator ride of my 15 year old daughter and we rode Men In Black several times at the request of my 18 year old son. Jaws was brilliant as our guide was very entertaining, Twister was interesting but too short as was earthquake. Back to the Future was a great simulator ride for everyone. Waiting times were between 15 minutes and 25 which was nothing, and the air cooling systems for the queues were great. Food in the diners was fantastic This was our first time to UO and although it was hot and humid it didn't matter because the rides were so wonderious. We also visited Islands of Advenute where my teenagers experienced every gut wrenching roller coaster. I bought an Express Pass here to avoid queuing in the heat, but we didn't readlly need it because the queues were quite short. We had the most the amazing sandwiches and deserts at the Hard Rock Cafe which, even my son, a typical teenage gannet, could not finish much to his dismay. If you've never been to Universal Studios, go there, personally I think it's even more fun for adults than teenagers!                                                                                                                                                                                                                                                                                                                                                                                                                                                 Universal Studios Florida      2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ..
# 4.0     June 25, 2017       Nice place for kids and adults alike                                     Went with my 5 and 3 year old. Unlike what I had expected had more than enough rides for such small kids as well. The transformers, puss in boots , Jurassic rapid adventure and enchanted airways were some of the most loved roller coaster rides by my 5 year old. During school holidays, if you don't have an express entry it can be quite frustrating. After waiting for 30 min for my first ride, I decided to upgrade to express, or the kids are most likely to miss the fun and remember just the frustration of queuing up in the sweltering heat!.  The waterworld show is fantastic. Lots of efforts seems to have gone in enacting those stunts live. Really commendable. The general feel of walking through the USS streets after all the shows/rides have shut down, late in the evening is quite nice. It is actually like walking on the streets of a Disney movie. The fireworks on Saturday 8.30 pm is spectacular.  The heat can be unbearable. If going with small kids, spending more than 2-3 hours at a stretch at USS may end up being cruel to them. Much better to take a multi day or seasons pass and enjoy the place bit by bit, will be more relishing                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Universal Studios Singapore    1
#                             The clever park                                                          This is the clever part of the two part Universal adventure where rides have become highly effective simulators, therefore indoors, not prone to rain or heat and far less mechanical breakdowns. This is a good fun place and some of the attractions are truly world class – especially the two Harry Potter rides which are a must. Like Disney, Universal now makes queueing part of the experience, but this does show up some of the older attractions such as Poseidon’s adventure, which must have reached its sell by date. When I first went to universal in LA back in the 70s, it was a tour of the back lot, now this is a modern theme park but still retains that cinematic magic, hence the focus on simulators and CGI. Well worth spending a day or two and as always, get there early and head for the back of the park.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Universal Studios Florida      1
#         June 25, 2018       Amazing - Something for Everyone                                         Had an amazing 10 day holiday - visiting all 3 Universal Parks!! My mum n dad (who don’t do rides) enjoyed walking round, taking it all in, the shows and parades just as much we did!! They actually even went on a few rides!! A great family holiday - just as amazing as the first time we visited ( this is our third and won’t be our last time ),, the park Itself it very clean, lots of staff around to help with any issues and everyone is soo Friendly! It’s worth buying the refillable drinks at $14.99 and $8.50 for additional Days (1 between u is fine as you can top up every 10 minutes and there are loads of cold refreshing drinks to choose from) you have to try coke icee slush - surprisingly it was very refreshing although a little strange at first!! The pizza pretzel is also delicious!! Can’t wait to return!!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Universal Studios Florida      1
#                             Best Movie experience Rides for Teens & Family!!                         Experience rides of your movies in Universal Studios from Jurassic park to Transformers , lifetime experience, enjoyed with Family, 3D & 4D shows are great, & characters parade must see.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Universal Studios Florida      1
# 5.0     September 9, 2020   One of the top 10 places to visit in Singapore and a good day to spend!  I prefer that place during the Halloween month since It will be open at night! Other then that it is a good place to spend the day at sentosa!  We usually come there twice a year so we will always come back! Friends or family trips! Lovely dance performing groups and some fun attractions to check it out!  Will be back in oct!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Universal Studios Singapore    1
# Length: 50859, dtype: int64

# %%
# Remove duplicate records
usb_df.drop_duplicates(inplace=True)

# Recheck again by counting the records. The previous duplicate should be removed.
usb_df.value_counts()
# Out:
# rating  written_date       title                                                                    review_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     branch
# 1.0     April 1, 2013      Will not visit Universal again                                           We were in Florida visiting family for a week and traveled to Orlando to hit the two Universal parks. I will preface this review by saying we could not afford to purchase fast passes for our family of 5. The two days we were there the passes would have been $110 per person per day, meaning an extra $1,100 on top of the main ticket prices. That being said, the staff at Universal were incredibly rude. It is as though the bottom of the barrel were hired for this park (not the same at Islands of Adventure, the employees there were friendly.) Lines for not only rides were ridiculous but as well for food & drink. Let me also state that when I say rides, what that really means for the most park at Universal are show's and shaking chairs, not actual coasters for the most part. Add on long wait times made much worse if you could not pony up for the fast pass. We waited over 40 minutes in line for a turkey leg, only to get to the front of the line and be told they were out and it would be at least another 20-25 minutes. As long as this park has been in business you would think they would have a better idea of how do run it. We waited until our kids were a bit older to go to Universal as we were told the rides were geared more for older kids. That was not the case. The few coasters they had were good provided you had the patience to wait for 2-3 hours in line, but the Disney parks are not only a better deal (free fast pass, friendly employees, better food options) but they have more actual rides. We will not be returning to any of the Universal Parks in the future.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Universal Studios Florida      1
# 5.0     July 1, 2016       Such a great time!!                                                      My husband and I spent three days at Universal and loved every minute! We got the double park pass from AAA for less than $400. We went on "less crowded" days: Saturday-Monday and rode single rider whenever possible. We were able to see everything we wanted to see and ride every ride we wanted to ride, sometimes twice or more! We are HUGE Harry Potter fans and Diagon Alley and Hogsmeade were incredible. I love that Universal lets you bring in drinks and backpacks. A lot of rides have free lockers you can use. Everything seemed better set up than Disney, less expensive, and LESS CROWDED. We had the time of our lives!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Universal Studios Florida      1
#                            Wonderful Trip for our family!                                           We took our whole family kids and grandkids and everyone had a wonderful time! The rides were fun and exciting and there was fun areas for everyone.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Universal Studios Florida      1
#                            i fell inlove                                                            ive always loved going to theme parks, i absolutely love this place it brought out the kid in me, my boyfriend and i had a good time. plus we got a free minion notepad when we used our credit card                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Universal Studios Singapore    1
#                            new rides                                                                from I was young a lot has change and improved a lot. The theme-park is amazing, I love every ride. The rip rocket roller coaster is scary as hell lol but enjoyed my two days on each park. will be back next year. But get express passes because the lines are very long. Because the rides are exciting.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Universal Studios Florida      1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ..
# 4.0     June 25, 2016      Expensive but fun!                                                       We love spending time at Universal Studios but it is so expensive! Even our military tickets were pricey if you are just trying to go for a day or two, but we decided on getting the fast pass to make the most of our time, which added another $100 per person per day-ouch! We stayed from park opening at 9 until about 4pm and held a tight schedule but made it through 3 Harry Potter rides and 3 water rides. The Harry Potter rides we wanted were not eligible for the fast pass and took all morning-but do these first when lines are shortest. We went straight to the castle and waited only about 30 minutes, grabbed butter beer, took the Hogwarts Express to Diagonal Alley, and went to Gringotts, which was longer-about 45 minutes and by that time and it was lunch time. So really our fast passes were only used in the afternoon for water rides. We had to fit rides in one day since we had a babysitter so this packed day had time for absolutely no shopping. Everyone's schedule is different but I'd recommend a park hopper, 2-3 days total-do all Harry Potter and shopping in one day or shop a separate day and do a fast pass for one day and hit all the other rides on that day-it makes a huge difference in your wait times, I just hate that I spent so much on it and only got to use it for a few hours and 3 rides. Bring bottled water and wear comfortable shoes!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Universal Studios Florida      1
#                            Great; Similar to other US; A fat man's perspective                      To start, I absolutely loved this park. It was very similar to all the other Universal Studios around the world (I've been to them all now) but with some rides unique to Japan. Before going, I had tried to do some research on ride sizes as I am not a small man (240lbs, 5'4") and I knew that there wouldn't be as many concessions for bigger guests as the parks in the USA has. Unfortunately, there isn't much information so I hope to give that here.  Firstly, I highly suggest that if you're wanting to arrive at Park Open, and you're going on a weekend, that you arrive at least an hour before. I arrived 45 minutes before and was quite a ways back from the ticket window. By the time I got in, it was 15 minutes after park open.  If you plan to go to the Wizarding World of Harry Potter, please note that they have timed entry. I suggest going to the lake (check the map) where they issue entrance tickets (for free) before you do anything else. This will give you a time frame in which you can enter. Once you leave, you can't go back in (though after 6pm it appears they open the "gates" to everyone). However, if you buy an Express Pass that includes Forbidden Journey they give you an entry pass to WWoHP automatically.  Shows: I avoided most of the timed shows as I don't know Japanese and didn't feel it would be worth my time. The only ones I saw were the ones that happen on the street (in front of Mel's Diner and in WWoHP). These were a mix of Japanese and English and were great fun.  Food: Standard theme park fare. Expensive and fairly monotonous in that most places offered the same types of meals just with different names it seemed.  Rides: This is where being a bigger guy was to my downfall. Many rides have sample seats that you can test out to make sure you can fit. For the most part I found the staff to be very proactive in getting me into the test seats, but at the same time fairly timid so as not to offend. If you're a bigger guest, go in expecting to have to sit in the test seats each time. I made sure to go up to the staff first and request to sit in them as that limits any embarrassment on either participants part.  My circumference, measured around the widest part of my belly, was 51 inches. This did not prevent me from riding any rides. The rides with restraints that test this are as follows:  Harry Potter and the Forbidden Journey (lots of room left even with my belly) The Flying Dinosaur (it locked on the widest latch possible. If I was a couple inches bigger around, I would not be able to ride it)  The only other ride with a test seat, The Hollywood Dream rollercoaster, is a lap bar. Sitting down, the circumference of my thighs was 48 inches. This was too big for the ride and I wasn't able to go on this ride. I was told that if I was an inch or two smaller it'd work. But alas. If you've been on the Rip Rocket in Orlando, it's a similar style of restraint.  All in all I had a blast here.  Universal Studios Japan        1
#                            Lots of Rides on the Rise                                                Universal Studios is definitely on the move. For a while in the past, it had been getting a bit stale, with attractions based on movies that a dying population identified with (Jaws, E.T.), but it's finally been updated with more current/timeless culture (Simpsons, Shrek, Minions, Transformers, Mummy, Dr. Seuss). I think it's time that Men in Black moved on, but the addition of Harry Potter features was a good move.  My biggest complaint about Universal is that they pricegouge. They charge (steeply) for the fast-pass-style system that Disney offers as part of regular admission (which is also cheaper at Disney), AND make ticket purchase specific to the date, which leaves the customer without flexibility in the schedule. After purchasing a two-park, one-day express ticket, I have to say I felt ripped off (especially since the Hulk rollercoaster was closed, and the King Kong ride was not yet open-both these at the Isles of Adventure). DON'T buy the express pass -it's not worth it, and if you're there on a busy day, just use the single rider lane, and you'll make it to most if not all rides.  There are some really good rides here (the mummy rollercoaster is great), but at the end of the day, it's not Disney World. I felt like a customer rather than a guest. It ain't cheap!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Universal Studios Florida      1
#                            Quick vacation                                                           One day to splurge n have fun. Fast Passes available, memorabilia beverage cups with discounted refills, lines for rides were fairly quick, and workers were generally friendly. We got a deal on their all day dining which includes 1 entree, drink, side/dessert per hour. Staying one full day, it was totally worth it. A couple of rides were having intermittent hiccups which was a small inconvenience as they were typically down for less than 15 minutes for running diagnostics and ghost-runs.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Universal Studios Florida      1
# 5.0     September 9, 2020  One of the top 10 places to visit in Singapore and a good day to spend!  I prefer that place during the Halloween month since It will be open at night! Other then that it is a good place to spend the day at sentosa!  We usually come there twice a year so we will always come back! Friends or family trips! Lovely dance performing groups and some fun attractions to check it out!  Will be back in oct!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Universal Studios Singapore    1
# Length: 50859, dtype: int64

# %% [markdown]
# ### 3.4 Display basic statistical information in usb_df

# %%
# Display basic statistical information in the dataframe using describe() function.
usb_df.describe()
# Out:
#              rating
# count  50859.000000
# mean       4.257142
# std        1.046513
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
# Dropping title and written_date - unneeded
usb_df = usb_df.drop(['title', 'written_date', ], axis = 1)
usb_df.dropna(inplace = True)

# Remove spaces in columns and replace them with underscore 
usb_df.columns = usb_df.columns.str.replace(" ", "_")

# Set the name of the columns to all lowercase
usb_df.columns = map(str.lower, usb_df.columns)

# Recheck dropped columns
usb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50859 entries, Kelly B to sc_myinitial
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rating       50859 non-null  float64
#  1   review_text  50859 non-null  object
#  2   branch       50859 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 3.5 Create Polarity Rating to determing rating based on review

# %%
# Create new column of Polarity rating - Assign whether the rating was either Positive/Neutral/Negative
# 4-5 - Positive, 3 - Neutral, 1-2 - Negative
usb_df['polarity_rating'] = usb_df['rating'].apply(lambda x: 'Positive' if x > 3 else('Neutral' if x == 3 else 'Negative'))

# Check the newly added Polarity Rating
usb_df.head()
# Out:
#                  rating                                        review_text  \
# reviewer
# Kelly B             2.0  We went to Universal over Memorial Day weekend...
# Jon                 1.0  The food service is horrible. I’m not reviewin...
# Nerdy P             2.0  I booked this vacation mainly to ride Hagrid m...
# ran101278           4.0  When a person tries the test seat for the ride...
# tammies20132015     5.0  Ok, I can't stress enough to anyone and everyo...
#
#                                     branch polarity_rating
# reviewer
# Kelly B          Universal Studios Florida        Negative
# Jon              Universal Studios Florida        Negative
# Nerdy P          Universal Studios Florida        Negative
# ran101278        Universal Studios Florida        Positive
# tammies20132015  Universal Studios Florida        Positive

# %% [markdown]
# ### 3.6 Data Visualization on Rating & Polarity Rating

# %%
# Total number of respondents based on branch
sns.catplot(x="branch", kind="count", palette="tab10", data=usb_df, height=5, aspect=3.4)
plt.title("Total Respondents According to Branch")
plt.xlabel("branch")
plt.ylabel("Number of Respondents")
# Out:
# Text(-12.805555555555534, 0.5, 'Number of Respondents')

# %%
# Display the count of each of the rating - 5 being the highest count
sns.set_style("whitegrid")
sns.countplot(x = "rating", data = usb_df, palette = "YlGnBu_r")
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
# Count each rating with branch
sns.catplot(x = 'rating', col = 'branch', data = usb_df, kind = 'count')

# %%
# Display the count of polarity rating - Positive has the highest count
sns.set_style('whitegrid')
sns.countplot(x = 'polarity_rating', data = usb_df, palette = 'summer')
# Out:
# <AxesSubplot:xlabel='polarity_rating', ylabel='count'>

# %%
# Count each polarity rating with branch
sns.catplot(x = 'polarity_rating', col = 'branch', data = usb_df, kind = 'count')

# %% [markdown]
# ###  3.7 Differentiate Polarity Rating which is positive, neutral, negative

# %%
# Create a dataframe for each of the polarity rating - take the first 8000 for positive rating
df_Positive = usb_df[usb_df['polarity_rating'] == 'Positive'][0:8000]
df_Neutral = usb_df[usb_df['polarity_rating'] == 'Neutral']
df_Negative = usb_df[usb_df['polarity_rating'] == 'Negative']

print ("df_Positive shape: ", df_Positive.shape)
print ("df_Neutral shape: ", df_Neutral.shape)
print ("df_Negative shape: ", df_Negative.shape)
# Out:
# df_Positive shape:  (8000, 4)
# df_Neutral shape:  (5226, 4)
# df_Negative shape:  (3953, 4)

# %%
# Display the first five data frame for Positive
df_Positive.head()
# Out:
#                  rating                                        review_text  \
# reviewer
# ran101278           4.0  When a person tries the test seat for the ride...
# tammies20132015     5.0  Ok, I can't stress enough to anyone and everyo...
# Jen                 4.0  We spent 6 nights on site at Sapphire Falls as...
# Mandee L            5.0  Universal Adventure Park was the best out of t...
# Nancy C             5.0  For all ages rides and restaurants lots of pho...
#
#                                     branch polarity_rating
# reviewer
# ran101278        Universal Studios Florida        Positive
# tammies20132015  Universal Studios Florida        Positive
# Jen              Universal Studios Florida        Positive
# Mandee L         Universal Studios Florida        Positive
# Nancy C          Universal Studios Florida        Positive

# %%
# Display the first five data frame for Neutral
df_Neutral.head()
# Out:
#              rating                                        review_text  \
# reviewer
# Wendy L         3.0  Many fun simulator rides and I love the "Wizar...
# amway60436      3.0  First off most of the information given to me ...
# Kathy E         3.0  My husband and I visited Universal a couple ye...
# Krosener314     3.0  we had the dining pass but the wait times were...
# GJPRUD          3.0  Wait in long lines everywhere. Ok so there is ...
#
#                                 branch polarity_rating
# reviewer
# Wendy L      Universal Studios Florida         Neutral
# amway60436   Universal Studios Florida         Neutral
# Kathy E      Universal Studios Florida         Neutral
# Krosener314  Universal Studios Florida         Neutral
# GJPRUD       Universal Studios Florida         Neutral

# %%
# Display the first five data frame for Negative
df_Negative.head()
# Out:
#               rating                                        review_text  \
# reviewer
# Kelly B          2.0  We went to Universal over Memorial Day weekend...
# Jon              1.0  The food service is horrible. I’m not reviewin...
# Nerdy P          2.0  I booked this vacation mainly to ride Hagrid m...
# John             1.0  Worst experience I have ever had the rides are...
# annapN7702ZW     2.0  I just expected more. Alot of waiting around, ...
#
#                                  branch polarity_rating
# reviewer
# Kelly B       Universal Studios Florida        Negative
# Jon           Universal Studios Florida        Negative
# Nerdy P       Universal Studios Florida        Negative
# John          Universal Studios Florida        Negative
# annapN7702ZW  Universal Studios Florida        Negative

# %%
# Taking sample from the current list from Neutral & Negative to complete 8000 count.
df_Neutral_over = df_Neutral.sample(8000, replace = True)
df_Negative_over = df_Negative.sample(8000, replace = True)

# Display all of the current shape to be combined
print ("df_Positive shape: ", df_Positive.shape)
print ("df_Neutral_over shape: ", df_Neutral_over.shape)
print ("df_Negative_over shape: ", df_Negative_over.shape)

# Combine all the data frame with 8000 rows in one data frame (df)
df = pd.concat([df_Positive, df_Neutral_over, df_Negative_over], axis = 0)

# Display the combined data frame
print ("Overall df shape: ", df.shape)
# Out:
# df_Positive shape:  (8000, 4)
# df_Neutral_over shape:  (8000, 4)
# df_Negative_over shape:  (8000, 4)
# Overall df shape:  (24000, 4)

# %% [markdown]
# ### 3.8 Data Process

# %%
# Removing stopwords & punctuation is required - using nltk library. 
# We would not want these words to take up space in our database, or taking up valuable processing time.
# A stopword is a commonly used word (such as “the”, “a”, “an”, “in”) that a search engine has been programmed to ignore, 
# both when indexing entries for searching and when retrieving them as the result of a search query.
# We would not want these words to take up space in our database, or taking up valuable processing time.

def get_text_processing(text):
    
    # Get the stopword list from stopwords library (english)
    stpword = stopwords.words('english')
    
    # Get the character that is not in the list of punctuation 
    # Punctuation: full stops, question marks, commas, colons and semi-colons, exclamation marks and quotation marks.
    no_punctuation = [char for char in text if char not in string.punctuation]
    
    # Join / combine the character without no punctuation
    no_punctuation = ''.join(no_punctuation)
    
    # Return the 
    return ' '.join([word for word in no_punctuation.split() if word.lower() not in stpword])

# %%
# Apply the method "get_text_processing" into column review text
df['review'] = df['review_text'].apply(get_text_processing)

# Display the first five record - notice that the review already removed several characters.
df.head()
# Out:
#                  rating                                        review_text  \
# reviewer
# ran101278           4.0  When a person tries the test seat for the ride...
# tammies20132015     5.0  Ok, I can't stress enough to anyone and everyo...
# Jen                 4.0  We spent 6 nights on site at Sapphire Falls as...
# Mandee L            5.0  Universal Adventure Park was the best out of t...
# Nancy C             5.0  For all ages rides and restaurants lots of pho...
#
#                                     branch polarity_rating  \
# reviewer
# ran101278        Universal Studios Florida        Positive
# tammies20132015  Universal Studios Florida        Positive
# Jen              Universal Studios Florida        Positive
# Mandee L         Universal Studios Florida        Positive
# Nancy C          Universal Studios Florida        Positive
#
#                                                             review
# reviewer
# ran101278        person tries test seat rides gets green light ...
# tammies20132015  Ok cant stress enough anyone everyone go Unive...
# Jen              spent 6 nights site Sapphire Falls family 6 2 ...
# Mandee L         Universal Adventure Park best two went impress...
# Nancy C          ages rides restaurants lots photo opportunitie...

# %%
# Create new data frame containing only the review and Polarity_Rating, assign to the same data frame
df = df[['review', 'polarity_rating']]
df.head()
# Out:
#                                                             review  \
# reviewer
# ran101278        person tries test seat rides gets green light ...
# tammies20132015  Ok cant stress enough anyone everyone go Unive...
# Jen              spent 6 nights site Sapphire Falls family 6 2 ...
# Mandee L         Universal Adventure Park best two went impress...
# Nancy C          ages rides restaurants lots photo opportunitie...
#
#                 polarity_rating
# reviewer
# ran101278              Positive
# tammies20132015        Positive
# Jen                    Positive
# Mandee L               Positive
# Nancy C                Positive

# %%
# Apply data manipulation of get_dummies to convert categorical into dummy/indicator variable - store in dummy_df.
dummy_df = pd.get_dummies(df["polarity_rating"])

# Drop the polarity_rating column from usb_df.
df.drop(["polarity_rating"], axis = 1, inplace = True)

# Combine the usb_df & dummy_df to get the final data frame
final_usb_df = pd.concat([df, dummy_df], axis = 1)

# Display the first five records in the data frame
final_usb_df.head()
# Out:
#                                                             review  Negative  \
# reviewer
# ran101278        person tries test seat rides gets green light ...         0
# tammies20132015  Ok cant stress enough anyone everyone go Unive...         0
# Jen              spent 6 nights site Sapphire Falls family 6 2 ...         0
# Mandee L         Universal Adventure Park best two went impress...         0
# Nancy C          ages rides restaurants lots photo opportunitie...         0
#
#                  Neutral  Positive
# reviewer
# ran101278              0         1
# tammies20132015        0         1
# Jen                    0         1
# Mandee L               0         1
# Nancy C                0         1

# %% [markdown]
# ### 3.9 WordCloud Data Visualization

# %%
# Using the wordcloud library
# df = pd.read_csv("universal_studio_branches.csv")
df = df_Neutral

comment_words = ''
stopwords = set(STOPWORDS)

# Iterate through the csv file
for val in df["review_text"]:

    # Typecaste each val to string
    val = str(val)
    
    # Split the value
    tokens = val.split()

    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()

    comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 500, height = 500, 
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# Plot the WordCloud image                      
plt.figure(figsize = (10, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# Using the wordcloud library
# df = pd.read_csv("universal_studio_branches.csv")
df = df_Positive

comment_words = ''
stopwords = set(STOPWORDS)

# Iterate through the csv file
for val in df["review_text"]:

    # Typecaste each val to string
    val = str(val)
    
    # Split the value
    tokens = val.split()

    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()

    comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 500, height = 500, 
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# Plot the WordCloud image                      
plt.figure(figsize = (10, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# Using the wordcloud library
# df = pd.read_csv("universal_studio_branches.csv")
df = df_Negative

comment_words = ''
stopwords = set(STOPWORDS)

# Iterate through the csv file
for val in df["review_text"]:

    # Typecaste each val to string
    val = str(val)
    
    # Split the value
    tokens = val.split()

    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()

    comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 500, height = 500, 
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# Plot the WordCloud image                      
plt.figure(figsize = (10, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
